# %%
Imports

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
print('The shape of the training inputs:', X_train.shape)
print('The shape of the training labels:',y_train.shape)
print('The shape of the testing inputs:',X_test.shape)
print('The shape of the testing labels:',y_test.shape)
# Out:
# The shape of the training inputs: (60000, 28, 28)
# The shape of the training labels: (60000,)
# The shape of the testing inputs: (10000, 28, 28)
# The shape of the testing labels: (10000,)

# %%
fig, axs = plt.subplots(4, 4)
cnt = 0
for i in range(4):
     for j in range(4):
         axs[i, j].imshow(X_train[cnt])
         cnt += 1

# %%
X_train = tf.keras.utils.normalize(X_train, axis=1)
X_test = tf.keras.utils.normalize(X_test, axis=1)

# %%
X_train = X_train / 255
X_test = X_test / 255
print('The shape of the training inputs:', X_train.shape)
print('The shape of the training labels:',y_train.shape)
print('The shape of the testing inputs:',X_test.shape)
print('The shape of the testing labels:',y_test.shape)
# Out:
# The shape of the training inputs: (60000, 28, 28)
# The shape of the training labels: (60000,)
# The shape of the testing inputs: (10000, 28, 28)
# The shape of the testing labels: (10000,)

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Flatten(input_shape=(784,)))   # input layer

# %%
model.add(tf.keras.layers.Dense(units=128, activation=tf.nn.relu))   # 1st hidden layer
model.add(tf.keras.layers.Dense(units=128, activation=tf.nn.relu))   # 2nd hidden layer

# %%
model.add(tf.keras.layers.Dense(units=10, activation=tf.nn.softmax))   # output layer

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,282 (462.04 KB)
#  Trainable params: 118,282 (462.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
X_train = X_train.reshape(X_train.shape[0], 28*28)
X_test = X_test.reshape(X_test.shape[0], 28*28)
print('The shape of the training inputs:', X_train.shape)
print('The shape of the training labels:',y_train.shape)
print('The shape of the testing inputs:',X_test.shape)
print('The shape of the testing labels:',y_test.shape)
train_model = model.fit(X_train, y_train, epochs=10, batch_size=100)
# Out:
# The shape of the training inputs: (60000, 784)
# The shape of the training labels: (60000,)
# The shape of the testing inputs: (10000, 784)
# The shape of the testing labels: (10000,)
# Epoch 1/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5917 - loss: 1.2887
# Epoch 2/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8110 - loss: 0.6201
# Epoch 3/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8602 - loss: 0.4786
# Epoch 4/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8792 - loss: 0.4070
# Epoch 5/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8938 - loss: 0.3635
# Epoch 6/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9030 - loss: 0.3334
# Epoch 7/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9090 - loss: 0.3102
# Epoch 8/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9143 - loss: 0.2920
# Epoch 9/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9187 - loss: 0.2766
# Epoch 10/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9234 - loss: 0.2620

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(loss)
print(accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9261 - loss: 0.2551
# 0.2551160156726837
# 0.9261000156402588

# %% [markdown]
# # User
# yes

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(loss)
print(accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0713 - loss: 2.3026
# 2.3026227951049805
# 0.07129999995231628

# %%
prediction = model.predict([X_test])
prediction
# Out:
#  88/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# c:\AD331\linearRegressions\env\Lib\site-packages\keras\src\models\functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_11
# Received: inputs=('Tensor(shape=(32, 784))',)
#   warnings.warn(msg)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# c:\AD331\linearRegressions\env\Lib\site-packages\keras\src\models\functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_11
# Received: inputs=('Tensor(shape=(None, 784))',)
#   warnings.warn(msg)
# array([[6.1755520e-05, 1.6948247e-08, 2.1238596e-04, ..., 9.9721283e-01,
#         7.1600466e-06, 7.9736131e-04],
#        [3.9949948e-05, 2.3286093e-05, 9.9045068e-01, ..., 5.0216515e-11,
#         3.3386692e-04, 2.0590704e-11],
#        [7.7732203e-09, 9.9802339e-01, 5.1238324e-04, ..., 2.4414583e-04,
#         4.9797026e-04, 6.4699570e-06],
#        ...,
#        [3.5247787e-08, 2.2574073e-05, 1.2299368e-05, ..., 4.9348007e-04,
#         1.6837557e-03, 2.5302732e-02],
#        [6.6931522e-04, 1.4382639e-04, 4.5039800e-05, ..., 2.4568942e-06,
#         6.9668636e-02, 4.8583010e-05],
#        [1.2967497e-03, 3.1116137e-08, 1.2937962e-03, ..., 3.1852821e-08,
#         4.0652476e-06, 9.6073599e-08]], shape=(10000, 10), dtype=float32)

# %%
model.save("Digit_Recognition_trained_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test = 53
print('Probabilities: ', prediction[test])
print('\n')
print('Prediction: ', np.argmax(prediction[test]))
# Out:
# Probabilities:  [2.8799486e-04 2.5386413e-04 6.7133289e-05 1.9886352e-02 8.9763798e-04
#  9.6801847e-01 6.9217000e-04 1.3746348e-05 9.0854075e-03 7.9726556e-04]
#
#
# Prediction:  5

# %%
plt.imshow(X_test[test].reshape(28, 28), cmap='gray')  # Added reshape and cmap='gray' for better visualization
plt.show()
